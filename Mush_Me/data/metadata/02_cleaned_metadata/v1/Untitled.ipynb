# %%
import pandas as pd
from __future__ import print_function, division
import numpy as np

# %%
pwd
# Out:
# '/Users/camille/code/hadri96/Mush_Me/Mush_Me/data/metadata/02_cleaned_metadata/v1'

# %%
df = pd.read_csv("metadata_mini_train.csv")
df
# Out:
#        Unnamed: 0  level_0  index        date    year  month   day  \
# 0               0        0      0  2020-09-17  2020.0    9.0  17.0
# 1               1        1      1  2017-08-16  2017.0    8.0  16.0
# 2               2        2      2  2020-07-23  2020.0    7.0  23.0
# 3               3        3      3  2018-09-09  2018.0    9.0   9.0
# 4               4        4      4  2011-08-20  2011.0    8.0  20.0
# ...           ...      ...    ...         ...     ...    ...   ...
# 31206       31248    31481  32748  2020-10-31  2020.0   10.0  31.0
# 31207       31249    31482  32749  2018-08-24  2018.0    8.0  24.0
# 31208       31250    31483  32750  2014-02-10  2014.0    2.0  10.0
# 31209       31251    31484  32751  2020-10-11  2020.0   10.0  11.0
# 31210       31252    31485  32752  2018-09-04  2018.0    9.0   4.0
#
#       countryCode  taxonID                       scientificName  ...  \
# 0              DK  17215.0     Mycena crocata (Schrad.) P.Kumm.  ...
# ...

# %%
np.unique
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-d1e1ae5dfc02> in <module>
# ----> 1 df.loc[Habitat]
#
# NameError: name 'Habitat' is not defined
