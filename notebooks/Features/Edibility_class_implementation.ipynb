# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#from Mush_Me.metadata import Data
import os
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# !pwd
# %reload_ext autoreload
# Out:
# /Users/hadrienmorand/code/hadri96/Mush_Me/notebooks/Features

# %%
file = Data('test')

path = '/Users/hadrienmorand/code/hadri96/Mush_Me/Mush_Me/data'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-e995a4cd7f16> in <module>
# ----> 1 file = Data('test')
#       2
#       3 path = '/Users/hadrienmorand/code/hadri96/Mush_Me/Mush_Me/data'
#
# NameError: name 'Data' is not defined

# %%
families = ['Agaricus',
'Amanita',
'Apioperdon',
'Auricularia',
'Boletus',
'Calvatia',
'Cantharellus',
'Chroogomphus',
'Clitocybe',
'Cortinarius',
'Craterellus',
'Entoloma',
'Hydnum',
'Imleria',
'Inocybe',
'Kuehneromyces',
'Laccaria',
'Lactarius',
'Leccinum',
'Lepista',
'Lyophyllum',
'Macrolepiota',
'Morchella',
'Mycena',
'Pleurotus',
'Russula',
'Sparassis',
'Suillus',
'Terfezia',
'Tricholoma',
'Tuber',
'Xerocomus']

# %%
data = file.create_mini_data_set_df(families, user_input=False, create_folders=True, create_new_directory=False)
data
# Out:
# /Users/hadrienmorand/code/hadri96/Mush_Me/Mush_Me/metadata.py:119: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data_filtered = data[data['kingdom']=='Fungi']\
# /Users/hadrienmorand/code/hadri96/Mush_Me/Mush_Me/metadata.py:119: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data_filtered = data[data['kingdom']=='Fungi']\
# ['.DS_Store', '00_initial', '02_By_Species_Dataset', '01_By_Species_Dataset']
# Please select in which directory you'd like to insert this new file:02_By_Species_Dataset
#            date    year  month   day countryCode  taxonID         phylum  \
# 0    2018-09-01  2018.0    9.0   1.0          DK  17215.0  Basidiomycota
# 1    2019-10-06  2019.0   10.0   6.0          DK  17215.0  Basidiomycota
# 2    2020-10-07  2020.0   10.0   7.0          DK  17215.0  Basidiomycota
# 3    2016-10-24  2016.0   10.0  24.0          DK  17215.0  Basidiomycota
# ...

# %%
data
# Out:
#              date    year  month   day countryCode  taxonID         phylum  \
# 0      2017-08-22  2017.0    8.0  22.0          DK  61200.0  Basidiomycota
# 1      2020-10-28  2020.0   10.0  28.0          DK  14861.0  Basidiomycota
# 2      2015-10-12  2015.0   10.0  12.0          DK  14861.0  Basidiomycota
# 3      2020-10-13  2020.0   10.0  13.0          DK  14861.0  Basidiomycota
# 4      2020-11-04  2020.0   11.0   4.0          DK  14861.0  Basidiomycota
# ...           ...     ...    ...   ...         ...      ...            ...
# 187849 2015-06-21  2015.0    6.0  21.0          DK  18155.0     Ascomycota
# 187850 2020-07-24  2020.0    7.0  24.0          DK  18155.0     Ascomycota
# 187851 2020-07-23  2020.0    7.0  23.0          DK  18155.0     Ascomycota
# 187852 2017-05-27  2017.0    5.0  27.0          DK  18155.0     Ascomycota
# 187853 2017-09-01  2017.0    9.0   1.0          DK  18155.0     Ascomycota
#
# ...

# %%
path = '/Users/hadrienmorand/code/hadri96/Mush_Me/Mush_Me/data'

path = os.path.join(path,'metadata','01_initial_metadata','Pilze_Speisewert.csv')

edibility_df = pd.read_csv(path, sep=';')
                           
edibility_df = edibility_df.rename(columns={"Name":"species","Wert": "Edibility", "Vorkommen": "Availability"})

edibility_df.drop(columns='NameDeutsch', inplace=True)

edibility_df
# Out:
#                      species        Edibility           Availability
# 0        Abortiporus biennis  kein Speisepilz                 selten
# 1     Acrospermum compressum  kein Speisepilz  verbreitet bis häufig
# 2     Adelphella babingtonii  kein Speisepilz  verbreitet bis häufig
# 3        Agaricus aestivalis           essbar                 selten
# 4           Agaricus altipes  kein Speisepilz                 selten
# ...                      ...              ...                    ...
# 3062      Xylaria carpophila  kein Speisepilz  verbreitet bis häufig
# 3063      Xylaria filiformis  kein Speisepilz  verbreitet bis häufig
# 3064       Xylaria hypoxylon  kein Speisepilz  verbreitet bis häufig
# 3065        Xylaria longipes  kein Speisepilz  verbreitet bis häufig
# 3066      Xylaria polymorpha  kein Speisepilz  verbreitet bis häufig
#
# [3067 rows x 3 columns]

# %%
edibility_df['Edibility'] = edibility_df['Edibility'].map({'kein Speisepilz':'Non Edible',
                                                 'essbar':'Edible',
                                                 'giftig':'Poisonous',
                                                 'Speisepilz':'Edible',
                                                 'giftverdächtig':'Poisonous',
                                                 'Kein Speisepilz':'Non Edible',
                                                 'jung essbar':'Edible',
                                                 'bedingt essbar':'Non Edible',
                                                 'als Gewürzpilz verwendbar':'Non Edible',
                                                 'tödlich giftig':'Poisonous',
                                                 'sehr giftig':'Poisonous',
                                                 'mit Alkohol giftig':'Poisonous',
                                                 'kein Speisepilz, leicht giftig':'Poisonous',
                                                 'kein Spiesepilz':'Non Edible',
                                                 'Gewürzpilz':'Non Edible',
                                                 'leicht giftig':'Poisonous',
                                                 'kein Speisepilz acha':'Non Edible',
                                                 'giftig, kleine Mengen als Gewürzpilz':'Poisonous',
                                                 'in Speisepilz':'Non Edible',
                                                 'kein Speisepilz, evtl. giftig':'Poisonous',
                                                 'essbar (Gewürz)':'Non Edible'})

# %%
edibility_df['Availability'] = edibility_df['Availability'].map({'selten':'Rare',
                                                           'verbreitet bis häufig':'Frequent'})

# %%
uncleaned_species_list = ['Agaricus arvensis',
 'Agaricus augustus',
 'Agaricus bernardii',
 'Agaricus bisporus',
 'Agaricus bitorquis',
 'Agaricus bohusii',
 'Agaricus brunneolus',
 'Agaricus campestris',
 'Agaricus crocodilinus',
 'Agaricus cupreobrunneus',
 'Agaricus dulcidulus',
 'Agaricus impudicus',
 'Agaricus langei',
 'Agaricus lanipes',
 'Agaricus litoralis',
 'Agaricus moelleri',
 'Agaricus subfloccosus',
 'Agaricus subperonatus',
 'Agaricus sylvaticus',
 'Agaricus sylvicola',
 'Agaricus xanthodermus',
 'Amanita ceciliae',
 'Amanita citrina',
 'Amanita crocea',
 'Amanita excelsa',
 'Amanita franchetii',
 'Amanita fulva',
 'Amanita gemmata',
 'Amanita lividopallescens',
 'Amanita muscaria',
 'Amanita pantherina',
 'Amanita phalloides',
 'Amanita porphyria',
 'Amanita rubescens',
 'Amanita strobiliformis',
 'Amanita submembranacea',
 'Amanita vaginata',
 'Amanita virosa',
 'Boletus aereus',
 'Boletus edulis',
 'Boletus ferrugineus',
 'Boletus pinophilus',
 'Boletus reticulatus',
 'Boletus subtomentosus',
 'Clitocybe agrestis',
 'Clitocybe costata',
 'Clitocybe diatreta',
 'Clitocybe fragrans',
 'Clitocybe gibba',
 'Clitocybe metachroa',
 'Clitocybe nebularis',
 'Clitocybe odora',
 'Clitocybe phaeophthalma',
 'Clitocybe phyllophila',
 'Clitocybe rivulosa',
 'Clitocybe squamulosa',
 'Clitocybe vibecina',
 'Mycena abramsii',
 'Mycena acicula',
 'Mycena aetites',
 'Mycena amicta',
 'Mycena arcangeliana',
 'Mycena aurantiomarginata',
 'Mycena belliae',
 'Mycena capillaripes',
 'Mycena capillaris',
 'Mycena chlorantha',
 'Mycena cinerella',
 'Mycena citrinomarginata',
 'Mycena clavicularis',
 'Mycena clavularis',
 'Mycena crocata',
 'Mycena diosma',
 'Mycena epipterygia',
 'Mycena erubescens',
 'Mycena filopes',
 'Mycena flavescens',
 'Mycena galericulata',
 'Mycena galopus',
 'Mycena haematopus',
 'Mycena inclinata',
 'Mycena juniperina',
 'Mycena leptocephala',
 'Mycena luteovariegata',
 'Mycena megaspora',
 'Mycena meliigena',
 'Mycena metata',
 'Mycena olivaceomarginata',
 'Mycena pelianthina',
 'Mycena polygramma',
 'Mycena pseudocorticola',
 'Mycena pterigena',
 'Mycena pura',
 'Mycena purpureofusca',
 'Mycena renati',
 'Mycena rosea',
 'Mycena rosella',
 'Mycena rubromarginata',
 'Mycena sanguinolenta',
 'Mycena silvae-nigrae',
 'Mycena stipata',
 'Mycena stylobates',
 'Mycena tenerrima',
 'Mycena tintinnabulum',
 'Mycena vitilis',
 'Mycena vulgaris',
 'Russula acrifolia',
 'Russula adusta',
 'Russula aeruginea',
 'Russula amoenolens',
 'Russula atropurpurea',
 'Russula atrorubens',
 'Russula aurea',
 'Russula aurora',
 'Russula betularum',
 'Russula brunneoviolacea',
 'Russula caerulea',
 'Russula cessans',
 'Russula chloroides',
 'Russula claroflava',
 'Russula cuprea',
 'Russula curtipes',
 'Russula cyanoxantha',
 'Russula decolorans',
 'Russula delica',
 'Russula densifolia',
 'Russula depallens',
 'Russula emetica',
 'Russula faginea',
 'Russula farinipes',
 'Russula faustiana',
 'Russula fellea',
 'Russula foetens',
 'Russula fragilis',
 'Russula grata',
 'Russula graveolens',
 'Russula grisea',
 'Russula heterophylla',
 'Russula illota',
 'Russula insignis',
 'Russula integra',
 'Russula ionochlora',
 'Russula laccata',
 'Russula laeta',
 'Russula luteotacta',
 'Russula maculata',
 'Russula melliolens',
 'Russula nauseosa',
 'Russula nitida',
 'Russula nobilis',
 'Russula ochroleuca',
 'Russula odorata',
 'Russula olivacea',
 'Russula paludosa',
 'Russula parazurea',
 'Russula pelargonia',
 'Russula praetervisa',
 'Russula pseudointegra',
 'Russula puellaris',
 'Russula queletii',
 'Russula risigallina',
 'Russula romellii',
 'Russula rosea',
 'Russula roseoaurantia',
 'Russula sanguinea',
 'Russula sardonia',
 'Russula seperina',
 'Russula silvestris',
 'Russula solaris',
 'Russula sororia',
 'Russula subrubens',
 'Russula velenovskyi',
 'Russula versicolor',
 'Russula vesca',
 'Russula veternosa',
 'Russula violeipes',
 'Russula virescens',
 'Russula viscida',
 'Russula xerampelina']

# %%
edibility_df['filter'] = edibility_df['species'].map(lambda x: 1 if x in uncleaned_species_list else 0)

# %%
edibility_df = edibility_df[edibility_df['filter']==1].reset_index().drop(columns=['index','filter','Availability'])

# %%
edibility_df.set_index('species', inplace=True)

# %%
edibility_df.to_dict()
# Out:
# {'Edibility': {'Agaricus arvensis': 'Edible',
#   'Agaricus augustus': 'Edible',
#   'Agaricus bisporus': 'Edible',
#   'Agaricus bitorquis': 'Edible',
#   'Agaricus campestris': 'Edible',
#   'Agaricus cupreobrunneus': 'Edible',
#   'Agaricus dulcidulus': 'Edible',
#   'Agaricus impudicus': 'Non Edible',
#   'Agaricus langei': 'Edible',
#   'Agaricus lanipes': 'Non Edible',
#   'Agaricus litoralis': 'Edible',
#   'Agaricus moelleri': 'Poisonous',
#   'Agaricus subfloccosus': 'Edible',
#   'Agaricus subperonatus': 'Edible',
#   'Agaricus sylvaticus': 'Edible',
#   'Agaricus sylvicola': 'Edible',
#   'Agaricus xanthodermus': 'Poisonous',
#   'Amanita ceciliae': 'Edible',
#   'Amanita citrina': 'Non Edible',
#   'Amanita crocea': 'Edible',
#   'Amanita excelsa': 'Non Edible',
#   'Amanita franchetii': 'Poisonous',
#   'Amanita fulva': 'Edible',
#   'Amanita gemmata': 'Non Edible',
#   'Amanita lividopallescens': 'Non Edible',
#   'Amanita muscaria': 'Poisonous',
# ...

# %%
big_df = data.merge(edibility_df,on='species')

# %%
big_df['Edibility'].unique()
# Out:
# array(['Non Edible', 'Poisonous', 'Edible'], dtype=object)

# %%
{'Agaricus arvensis': 'Edible',
  'Agaricus augustus': 'Edible',
  'Agaricus bernardii': ,
  'Agaricus bisporus': 'Edible',
  'Agaricus bitorquis': 'Edible',
  'Agaricus bohusii': ,
  'Agaricus brunneolus': ,
  'Agaricus campestris': 'Edible',
  'Agaricus crocodilinus': ,
  'Agaricus cupreobrunneus': 'Edible',
  'Agaricus dulcidulus': 'Edible',
  'Agaricus impudicus': 'Non Edible',
  'Agaricus langei': 'Edible',
  'Agaricus lanipes': 'Non Edible',
  'Agaricus litoralis': 'Edible',
  'Agaricus moelleri': 'Poisonous',
  'Agaricus subfloccosus': 'Edible',
  'Agaricus subperonatus': 'Edible',
  'Agaricus sylvaticus': 'Edible',
  'Agaricus sylvicola': 'Edible',
  'Agaricus xanthodermus': 'Poisonous',
  'Amanita ceciliae': 'Edible',
  'Amanita citrina': 'Non Edible',
  'Amanita crocea': 'Edible',
  'Amanita excelsa': 'Non Edible',
  'Amanita franchetii': 'Poisonous',
  'Amanita fulva': 'Edible',
  'Amanita gemmata': 'Non Edible',
  'Amanita lividopallescens': 'Non Edible',
  'Amanita muscaria': 'Poisonous',
  'Amanita pantherina': 'Poisonous',
  'Amanita phalloides': 'Poisonous',
  'Amanita porphyria': 'Poisonous',
  'Amanita rubescens': 'Edible',
  'Amanita strobiliformis': 'Edible',
  'Amanita submembranacea': 'Non Edible',
  'Amanita vaginata': 'Edible',
  'Amanita virosa': 'Poisonous',
  'Boletus aereus': 'Edible',
  'Boletus edulis': 'Edible',
  'Boletus ferrugineus': ,
  'Boletus pinophilus': 'Edible',
  'Boletus reticulatus': 'Edible',
  'Boletus subtomentosus': 'Edible',
  'Clitocybe agrestis': 'Non Edible',
  'Clitocybe costata': 'Edible',
  'Clitocybe diatreta': 'Poisonous',
  'Clitocybe fragrans': 'Poisonous',
  'Clitocybe gibba': 'Edible',
  'Clitocybe metachroa': 'Non Edible',
  'Clitocybe nebularis': 'Non Edible',
  'Clitocybe odora': 'Edible',
  'Clitocybe phaeophthalma': 'Poisonous',
  'Clitocybe phyllophila': 'Poisonous',
  'Clitocybe rivulosa': 'Poisonous',
  'Clitocybe squamulosa': 'Non Edible',
  'Clitocybe vibecina': 'Non Edible',
  'Mycena abramsii': 'Non Edible',
  'Mycena acicula': 'Non Edible',
  'Mycena aetites': 'Non Edible',
  'Mycena amicta': 'Non Edible',
  'Mycena arcangeliana': 'Non Edible',
  'Mycena aurantiomarginata': 'Non Edible',
  'Mycena capillaripes': 'Non Edible',
  'Mycena capillaris': 'Non Edible',
  'Mycena chlorantha': 'Non Edible',
  'Mycena cinerella': 'Non Edible',
  'Mycena citrinomarginata': 'Non Edible',
  'Mycena clavicularis': 'Non Edible',
  'Mycena clavularis': 'Non Edible',
  'Mycena crocata': 'Non Edible',
  'Mycena diosma': 'Non Edible',
  'Mycena epipterygia': 'Non Edible',
  'Mycena erubescens': 'Non Edible',
  'Mycena filopes': 'Non Edible',
  'Mycena flavescens': 'Non Edible',
  'Mycena galericulata': 'Non Edible',
  'Mycena galopus': 'Non Edible',
  'Mycena haematopus': 'Non Edible',
  'Mycena inclinata': 'Non Edible',
  'Mycena juniperina': ,
  'Mycena leptocephala': 'Non Edible',
  'Mycena luteovariegata': ,
  'Mycena megaspora': ,
  'Mycena meliigena': 'Non Edible',
  'Mycena metata': 'Non Edible',
  'Mycena olivaceomarginata': 'Non Edible',
  'Mycena pelianthina': 'Poisonous',
  'Mycena polygramma': 'Non Edible',
  'Mycena pseudocorticola': 'Non Edible',
  'Mycena pterigena': 'Non Edible',
  'Mycena pura': 'Poisonous',
  'Mycena purpureofusca': 'Non Edible',
  'Mycena renati': 'Non Edible',
  'Mycena rosea': 'Poisonous',
  'Mycena rosella': 'Non Edible',
  'Mycena rubromarginata': 'Non Edible',
  'Mycena sanguinolenta': 'Non Edible',
  'Mycena silvae-nigrae': 'Non Edible',
  'Mycena stipata': 'Non Edible',
  'Mycena stylobates': 'Non Edible',
  'Mycena tenerrima': ,
  'Mycena tintinnabulum': ,
  'Mycena vitilis': 'Non Edible',
  'Mycena vulgaris': 'Non Edible',
  'Russula acrifolia': 'Non Edible',
  'Russula adusta': 'Non Edible',
  'Russula aeruginea': 'Edible',
  'Russula amoenolens': 'Non Edible',
  'Russula atropurpurea': 'Non Edible',
  'Russula atrorubens': 'Non Edible',
  'Russula aurea': 'Edible',
  'Russula aurora': 'Edible',
  'Russula betularum': ,
  'Russula brunneoviolacea': 'Edible',
  'Russula caerulea': 'Edible',
  'Russula cessans': 'Edible',
  'Russula chloroides': 'Non Edible',
  'Russula claroflava': 'Edible',
  'Russula cuprea': 'Non Edible',
  'Russula curtipes': 'Edible',
  'Russula cyanoxantha': 'Edible',
  'Russula decolorans': 'Edible',
  'Russula delica': 'Non Edible',
  'Russula densifolia': 'Non Edible',
  'Russula depallens': ,
  'Russula emetica': 'Poisonous',
  'Russula faginea': 'Edible',
  'Russula farinipes': 'Non Edible',
  'Russula faustiana': ,
  'Russula fellea': 'Poisonous',
  'Russula foetens': 'Non Edible',
  'Russula fragilis': 'Non Edible',
  'Russula grata': 'Non Edible',
  'Russula graveolens': 'Edible',
  'Russula grisea': 'Edible',
  'Russula heterophylla': 'Edible',
  'Russula illota': 'Non Edible',
  'Russula insignis': 'Non Edible',
  'Russula integra': 'Edible',
  'Russula ionochlora': 'Edible',
  'Russula laccata': 'Non Edible',
  'Russula laeta': 'Edible',
  'Russula luteotacta': 'Non Edible',
  'Russula maculata': 'Non Edible',
  'Russula melliolens': 'Edible',
  'Russula nauseosa': 'Non Edible',
  'Russula nitida': 'Non Edible',
  'Russula nobilis': 'Poisonous',
  'Russula ochroleuca': 'Non Edible',
  'Russula odorata': 'Edible',
  'Russula olivacea': 'Non Edible',
  'Russula paludosa': 'Edible',
  'Russula parazurea': 'Edible',
  'Russula pelargonia': 'Non Edible',
  'Russula pseudointegra': 'Non Edible',
  'Russula puellaris': 'Non Edible',
  'Russula queletii': 'Non Edible',
  'Russula risigallina': 'Edible',
  'Russula romellii': 'Edible',
  'Russula rosea': 'Edible',
  'Russula roseoaurantia': ,
  'Russula sanguinea': 'Non Edible',
  'Russula sardonia': 'Non Edible',
  'Russula seperina': ,
  'Russula silvestris': ,
  'Russula solaris': 'Non Edible',
  'Russula sororia': ,
  'Russula subrubens': ,
  'Russula velenovskyi': 'Edible',
  'Russula versicolor': 'Non Edible',
  'Russula vesca': 'Edible',
  'Russula veternosa': 'Non Edible',
  'Russula violeipes': 'Edible',
  'Russula virescens': 'Edible',
  'Russula viscida': 'Non Edible',
  'Russula xerampelina': 'Edible'}
